# %% [markdown]
# ---
# hide: true
# toc: true
# layout: default
# title: Individual Review EL
# description: Recap of key events and learnings
# type: tangibles
# courses: { compsci: {week: 11} }
# ---

# %% [markdown]
# # Individual Review EL
#
# ## Recap of GitHub Issues
# During the Passion Project, I have tried to keep issues to track work and progress.
#
# [Online Issues](https://github.com/iKAN2025/frontend/issues) and summary below...
#
#
# - [Study -> Instrument Tracker](https://github.com/eunseolim123/student/issues/1).  This is the base of our Passion Project. It was taken from my Web Programming Basics assignment, but I changed things to adjust to the project.
#   - [Key Commit](https://github.com/iKAN2025/frontend/commit/d4b42e1abc80a78c25e4ccc5b480b58956097e62)
#   - [Study Tracker](http://localhost:4200/student/basics/html)
# - [Data Graphs + Sample](https://github.com/iKAN2025/frontend/issues/3).   This is a summary of how I made the first sample data graph that would reflect instrument practice for each user. The sample graph combines JavaScript and HTML. This integrates material from the second live review.
# - [Graphs Fix](https://github.com/iKAN2025/frontend/issues/7).   This is a quick discussion of the fixes to the graphs and the addition of 3 more graphs to account for each team member.
#   - [Key Commit](https://github.com/iKAN2025/frontend/commit/e9c97cd17d7d8528b3c7543c503a5eae28e0eb19)
# - [Images + Instrument Descriptions](https://github.com/iKAN2025/frontend/issues/6).  Addition amd resizing of images, lengthened descriptions on instrument types and CSS formatting for each tab on navigation bar.

# %% [markdown]
# ## Overview of Tracker
# Main Tracker Page.
#
# ### Code behind saving user data to local storage, retrieving and logging practice sessions in Practice Log. This code was essential for tracking and displaying a user's practice log over time.
# Essentially this code allows a musician to save, log, and view their practice over time. They can view a practice log that contains all of their practice times over the past few days and they can assess their performance.
#
# ```js
# <script>
#     // Event listener for the save button click
#     document.getElementById("save-button").addEventListener("click", function () {
#     // Get the practice time input value from the form
#     const practiceTime = document.getElementById("practice-time").value;
#
#     // Check if a valid practice time is entered
#     if (practiceTime !== "") {
#         // Get the current date in a readable format (e.g., "MM/DD/YYYY")
#         const currentDate = new Date().toLocaleDateString();
#
#         // Retrieve existing practice data from local storage, or initialize an empty object
#         const practiceData = JSON.parse(localStorage.getItem("practiceData")) || {};
#
#         // Saves the updated practice data back to local storage as a JSON string
#         practiceData[currentDate] = parseInt(practiceTime);
#
#         // Save the updated practice data back to local storage
#         localStorage.setItem("practiceData", JSON.stringify(practiceData));
#
#         // Display an alert confirming the saved practice time
#         alert(`Practice time (${practiceTime} minutes) saved for ${currentDate}`);
#
#         // Clear the input field after saving
#         document.getElementById("practice-time").value = "";
#
#         // Refresh the practice log display
#         // Retrieves saved data, logs it in practice log
#         displayWeeklyLog();
#     } else {
#         // Show an alert if no valid practice time is entered
#         alert("Please enter a valid practice time.");
#     }
# });
#
# // Function to display the weekly practice log
# function displayWeeklyLog() {
#     // Retrieve practice data from local storage, or initialize an empty object
#     const practiceData = JSON.parse(localStorage.getItem("practiceData")) || {};
#
#     // Get the table body element where the log will be displayed
#     const tableBody = document.querySelector("#weekly-log table tbody");
#
#     // Clear the existing content in the table body
#     tableBody.innerHTML = "";
#
#     // Iterate through each date in the practice data
#     for (const date in practiceData) {
#         // Create a new row in the table
#         const row = tableBody.insertRow();
#
#         // Create cells for date and practice time in the row
#         const cellDate = row.insertCell(0);
#         const cellTime = row.insertCell(1);
#
#         // Populate the cells with date and practice time data
#         cellDate.textContent = date;
#         cellTime.textContent = practiceData[date];
#     }
# }
#
# // Call the function to display the weekly practice log when the page loads
# displayWeeklyLog();
# </script>
# ```

# %% [markdown]
# ## Graphs
# I was also in charge of graphs that would allow a user to track their practice time over the days and compare their performance to other musicians.
#
# ```js
# <!-- Load Chart.js library -->
# // Chart.js is a JavaScript library for creating interactive and visually appealing charts
# <script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/2.9.4/Chart.js"></script>
# <!-- Define a container for the chart -->
# // Customizes the canvas for which the graph will be displayed on
# <div style="width: 575px; height: 330px;">
#     <canvas id="instrumentChart"></canvas>
# </div>
# <!-- JavaScript code to create the instrument practice time chart -->
# <script>
#     // Sample data for instrument practice time with date ranges
#     // Here I defined two arrays to store sample data
#     const practiceDates = ['10-07', '10-08', '10-09', '10-10', '10-11', '10-12', '10-13'];
#     const practiceTimes = [0, 40, 35, 50, 60, 45, 55, 40, 38, 42, 48, 50];
#     const practiceData = {
#         // Defines the structure of the chart data with customizations
#         labels: practiceDates,
#         datasets: [
#             {
#                 label: 'Practice Time per Day (Violin)',
#                 data: practiceTimes,
#                 borderColor: 'rgb(245, 66, 135)',
#                 fill: false,
#                 backgroundColor: 'rgb(242, 131, 174)',
#                 tension: 0.1,
#                 hoverBorderColor: 'orange'
#             }
#         ]
#     };
#     // Configures type of chart, provides data, customized scales, legend, and title
#     const practiceConfig = {
#         type: 'line',
#         data: practiceData,
#         options: {
#             scales: {
#                 x: {
#                     type: 'linear',
#                     position: 'bottom',
#                     title: {
#                         display: true,
#                         text: 'Date'
#                     }
#                 },
#                 y: {
#                     type: 'linear',
#                     position: 'left',
#                     title: {
#                         display: true,
#                         text: 'Minutes Practiced'
#                     }
#                 }
#             },
#             plugins: {
#                 legend: {
#                     display: false
#                 },
#                 title: {
#                     display: true,
#                     text: 'Instrument Practice Time per Day'
#                 }
#             }
#         }
#     };
#     // Get the context of the canvas element
#     // Retrieves Canvas element by its ID
#     // Initializes and renders chart with specified container
#     const practiceCtx = document.getElementById('instrumentChart').getContext('2d');
#     new Chart(practiceCtx, practiceConfig);
# </script>
# ```

# %% [markdown]
# ### Moving Background
# The moving background was also a big part of our project as it was incorporated on the tracker page itself.
#
# - Originally we were going to go with this moving piano background (code shown below), but ended up replacing the moving background with a gif due to frame issues
#   - Even if the frame was adjusted to fit the screen or the screen width of the particular device, each computer in our team showed a different display
#
# ```js
# <script>
# // Get the canvas element and its 2D rendering context
# const canvas = document.getElementById("alienWorld");
# const ctx = canvas.getContext('2d');
#
# // Constants for aspect ratio, maximum dimensions, and game speed
# const ASPECT_RATIO = {{WIDTH}} / {{HEIGHT}};
# const maxWidth = window.innerWidth;
# const maxHeight = window.innerHeight;
# var gameSpeed = 5;
#
# // Calculate dimensions and position for the canvas
# const canvasWidth = {{WIDTH}};
# const canvasHeight = canvasWidth / ASPECT_RATIO;
# const canvasLeft = 0; // Start from the left edge
# const canvasTop = (maxHeight - canvasHeight) / 2;
#
# // Set canvas dimensions and styles
# canvas.width = canvasWidth;
# canvas.height = canvasHeight;
# canvas.style.width = `${canvasWidth}px`;
# canvas.style.height = `${canvasHeight}px`;
# canvas.style.position = 'absolute';
# canvas.style.left = `${canvasLeft}px`;
# canvas.style.top = `${canvasTop}px`;
#
# // Define a layer class to represent a scrolling background layer
# class Layer {
#   constructor(image, speedRatio) {
#     this.x = 0;
#     this.y = 0;
#     this.width = {{WIDTH}};
#     this.height = {{HEIGHT}};
#     this.image = image;
#     this.speedRatio = speedRatio;
#     this.speed = gameSpeed * this.speedRatio;
#     this.frame = 0;
#   }
#   // Update the layer's position based on speed
#   update() {
#     this.x = (this.x - this.speed) % this.width;
#   }
#   // Draw the layer on the canvas
#   draw() {
#     ctx.drawImage(this.image, this.x, this.y);
#   }
# }
#
# // Create an instance of the Layer class for the background
# const backgroundImg = new Image();
# backgroundImg.src = '{{movingbg_csppassionproj}}';
# var backgroundObj = new Layer(backgroundImg, 0.5);
#
# // Function to update and draw the background layer
# function background() {
#   backgroundObj.update();
#   backgroundObj.draw();
#   requestAnimationFrame(background);
# }
#
# // Call the background function to start the animation loop
# background();
# </script>
# ```

# %% [markdown]
# ### Frontend Contributions
# As a frontend developer, I used HTML and CSS to make our project more visually appealing.
#
# - The code below shows the customizations that I made to enhance the visual aspect of our project.
# - This was put under 'includes' and embedded in each individual page of our project.
#
# ```js
# <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 20px;
#             background-color:white;
#         }
#          header {
#             background-color: #ffb6c1;
#             color: #fff;
#             padding: 10px;
#             text-align: center;
#         }
#         h1 {
#             margin: 0;
#         }
#         section {
#             max-width: 800px;
#             margin: 20px auto;
#             padding: 20px;
#             background-color:white;
#             box-shadow: 0 0 10px rgba(0, 0, 0, 0.3);
#             border-radius: 10px;
#             overflow: hidden;
#         }
#         footer {
#             background-color: #333;
#             color: #fff;
#             text-align: center;
#             padding: 10px;
#             position: fixed;
#             width: 100%;
#             bottom: 0;
#         }
# </style>
# ```

# %% [markdown]
# ## Dress Rehearsal Grading
#
# |Username   |Score|
# |-----------|-----|
# |jm1021     |9.1  |
# |Chrissiez  |8.6  |
# |srivaidyas |8.65 |
# |DanteA-tech|8.37 |
# |AdiBricks  |8.8  |
#
# Average: 8.704

# %% [markdown]
# ## N@TM Extra Credit Grading
#
# - [CSP P1 Jonathan, Soham, Gavin, Sri](https://github.com/spooketti/Phoenix/issues/5)
#   - 8.7/9
# - [CSP P1 Alara, Tara, Alisha, Sharon, Grace](https://github.com/tarasehdave/frontend/issues/12)
#   - 8.8/9
# - [CSP P5 Imaad, Tanay, Anika P, Anika B, Ananya](https://github.com/Imaad08/stocksFrontend/issues/1)
#   - 8.9/9

# %% [markdown]
# ## College Board 2018 Practice MCQ
# Plan: Do 22 questions in each sitting (total of 3 times)
# - Keep track of all questions I had to search up here on VSCode and take notes on topics I struggle with
# - Do all quiz corrections on here too
# - Watch corresponding College Board videos for topics I struggle with
#
# <mark><b>Questions I had to search up:</b></mark>
# - Question 3 (Skill 1.C): Definition of citizen science and examples
#   - Citizen science is also known as "crowdsourcing" or "crowd-sourced science," and it is the growing practice of public involvement in the gathering, analyzing, or sorting of scientific data for research purposes.
# - Question 6 (Skill 5.A): Role of the Internet Engineering Task Force (IETF)
#   - The IETF develops open standards through transparent processes with one goal in mind: to make the Internet work better.
# - Question 15 (Skill 5.A): Internet communication facts
#   - All devices connected to the internet are assigned an IP (Internet Protocol) address
# - Question 16 (Skill 5.E): Digital Millennium Copyright Act (DMCA)
#   - The DMCA criminalizes production and dissemination of technology, devices, or services intended to circumvent measures that control access to copyrighted works.
# - Question 17 (Skill 5.C): Definition of digitial divide and examples
#   - Digital divide is the gap between demographics and regions that have access to modern information and communications technology (ICT), and those that don't or have restricted access.
# - Question 39 (Skill 5.A): Open standards and protocols for Internet communication
#   - Open standards and protocols are used to prescribe the format of data sent over the Internet. This allows all connected hardware and software to communicate in a standard way.
# - Question 47 (Skill 5.E): Public key cryptography
#   - Public key cryptography is a method of encrypting or signing data with two different keys and making one of the keys, the public key, available for anyone to use. The other key (the private key) can be used to decrypt.
# - Question 51 (Skill 5.D): Definition of symmetric encryption and examples
#   - Symmetric encryption uses a single key to encrypt and decrypt.
# - Question 53 (Skill 5.C): Machine learning programs and their purpose
#   - Machine learning is the process of a computer analyzing data in order to make predictions and decisions based on trends in the data.
# - Question 58 (Skill 1.C): How the Internet enables crowdsourcing
#   - The Internet can provide tools, information, and knowledge to crowdsourcing participants and can lower geographic barriers to potential participants. However, there exist problems that cannot be solved in reasonable time, even with a distributed approach.
# - Question 59 (Skill 1.D): Lossy compression software definition
#   - In lossy compression, the data in a file is removed and not restored to its original form after decompression (the data is permanently removed).
# - Question 64 (Skill 5.C): How cloud computing has affected Internet communication
#   - Cloud computing is the delivery of different services through the Internet, including data storage, servers, databases, networking, and software.
#
# - Final Score: 66/66
#   - Reflction: I think this score was a result of me searching up every question I was unsure about, and I took several days to take my time and answer each question to the best of my ability.
#
# ## Pseudo Code
# - Question 20: Max (Max (a,b),c)
#   - This expression will first determine the maximum of a and b and then determine the maximum of the resulting value and c. This will result in the maximum of all three values.
# - Lot of questions with 'MISSING CODE', replacing a blank space with code
# - Question 27 shows numbered lines, determine where a certain piece of code should go

# %% [markdown]
# ## Trimester 1 Reflection
# I came into CSP knowing virtually (haha) nothing about coding in general. The only "code" I had done before was on Hour Of Code and other very simple tasks.
#
# - The Team Teaches were really helpful in understanding different concepts in CSP and College Board expectations
# - My favorite thing I experimented with was probably colors especially with the RGB values
#   - The CSS was also really fun and I think I learned a lot with style, now I know how to customize navigation bars, add headers, shadows, and footers! (A true Frontend Developer)
# - Incorporating data into code was a key point for me that combined the mathematics side of my brain with CSP
#   - I learned to store data in local storage using JSON and retrieve it to log
#   - I learned to make graphs in different ways, experimenting with Chart.js and also from the matplot.lib from the libraries Team Teach
#   - I think making code interactive is really interesting and I used that a lot in my Team Teach homework with user input
# - Working as a team grew my collaboration and communication skills
#   - I worked with new people that allowed me to branch out and expose myself to a new environment
#   - We communicated effectively on Slack and through texts, built lasting friendships
#   - I was really nervous and intimidated by this class but I felt comfortable asking questions to my team
# - Next trimester I hope to learn more about Backend, especially fetching data
#   - I want to expand more on my interest in user interaction and make my code more interactive
